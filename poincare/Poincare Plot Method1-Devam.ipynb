# %%
"""
Lazım olan paketlerimizi dahil ediyoruz
"""
# %matplotlib inline
import numpy as np
import random 
import matplotlib.pyplot as plt
from popfex import *

# %%
"""
Örnekler için zaman serisi verileri oluşturuyoruz
"""
x = np.arange(360)
x = np.array(x,float)*np.pi/180
ranSer = np.random.rand(360) # Rastgele değerlerle üretilmiş seri
sinSer = np.sin(x) # Sinüs fonksiyonu ile üretilmiş seri 
cosSer = np.cos(x) # Cosinüs fonksiyonu ile üretilmiş seri
multiSer = np.sin(x)*np.sin(x)-np.cos(3*x)+5  # sin(x)^2 - cos(3x) + 5 fonksiyonu ile üretilmiş seri  
multiSer2 = np.sin(x*x)-2*np.cos(x) + 3 # sin(x^2) - 2* cos(x) + 3 fonksiyonu ile üretilmiş seri  
tmp =ranSer+0.3*sinSer+0.6*multiSer2

# %%
showTimeSeries(ranSer)

# %%
showPoincare(ranSer)

# %%
showPoincareVect(ranSer)

# %%
showSMatrix(ranSer)

# %%
showTimeSeries(sinSer)

# %%
showPoincare(sinSer)

# %%
showPoincareVect(sinSer)

# %%
showSMatrix(sinSer)

# %%
showTimeSeries(cosSer)

# %%
showPoincareVect(cosSer)

# %%
showSMatrix(cosSer)

# %%
showTimeSeries(multiSer)

# %%
showPoincare(multiSer)

# %%
showPoincareVect(multiSer)

# %%
showSMatrix(multiSer)

# %%
showTimeSeries(multiSer2)

# %%
showPoincare(multiSer2)

# %%
showPoincareVect(multiSer2)

# %%
showSMatrix(multiSer2)

# %%
showTimeSeries(tmp)

# %%
showPoincare(tmp)

# %%
showPoincareVect(tmp)

# %%
showSMatrix(tmp)
